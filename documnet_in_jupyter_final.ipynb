# %%
Open PyCharm:

Open PyCharm and create a new project. Name it pyls_project.
Create Main Script File:

Right-click on the project folder and select New > Python File.
Name the file pyls.py.
Create JSON File:

Right-click on the project folder and select New > File.
Name the file structure.json.
Step 2: Implement Basic ls Functionality
Add Sample JSON Data:

Open structure.json and add the sample JSON data:
json

# %%
{
  "name": "interpreter",
  "size": 4096,
  "time_modified": 1699957865,
  "permissions": "-rw-r--r--",
  "contents": [
    {
      "name": ".gitignore",
      "size": 8911,
      "time_modified": 1699941437,
      "permissions": "drwxr-xr-x"
    },
    {
      "name": "LICENSE",
      "size": 1071,
      "time_modified": 1699941437,
      "permissions": "drwxr-xr-x"
    },
    {
      "name": "README.md",
      "size": 83,
      "time_modified": 1699941437,
      "permissions": "drwxr-xr-x"
    },
    {
      "name": "ast",
      "size": 4096,
      "time_modified": 1699957739,
      "permissions": "-rw-r--r--",
      "contents": [
        {
          "name": "go.mod",
          "size": 225,
          "time_modified": 1699957780,
          "permissions": "-rw-r--r--"
        },
        {
          "name": "ast.go",
          "size": 837,
          "time_modified": 1699957719,
          "permissions": "drwxr-xr-x"
        }
      ]
    },
    {
      "name": "go.mod",
      "size": 60,
      "time_modified": 1699950073,
      "permissions": "drwxr-xr-x"
    },
    {
      "name": "lexer",
      "size": 4096,
      "time_modified": 1699955487,
      "permissions": "drwxr-xr-x",
      "contents": [
        {
          "name": "lexer_test.go",
          "size": 1729,
          "time_modified": 1699955126,
          "permissions": "drwxr-xr-x"
        },
        {
          "name": "go.mod",
          "size": 227,
          "time_modified": 1699944819,
          "permissions": "-rw-r--r--"
        },
        {
          "name": "lexer.go",
          "size": 2886,
          "time_modified": 1699955487,
          "permissions": "drwxr-xr-x"
        }
      ]
    },
    {
      "name": "main.go",
      "size": 74,
      "time_modified": 1699950453,
      "permissions": "-rw-r--r--"
    },
    {
      "name": "parser",
      "size": 4096,
      "time_modified": 1700205662,
      "permissions": "drwxr-xr-x",
      "contents": [
        {
          "name": "parser_test.go",
          "size": 1342,
          "time_modified": 1700205662,
          "permissions": "drwxr-xr-x"
        },
        {
          "name": "parser.go",
          "size": 1622,
          "time_modified": 1700202950,
          "permissions": "-rw-r--r--"
        },
        {
          "name": "go.mod",
          "size": 533,
          "time_modified": 1699958000,
          "permissions": "drwxr-xr-x"
        }
      ]
    },
    {
      "name": "token",
      "size": 4096,
      "time_modified": 1699954070,
      "permissions": "-rw-r--r--",
      "contents": [
        {
          "name": "token.go",
          "size": 910,
          "time_modified": 1699954070,
          "permissions": "-rw-r--r--"
        },
        {
          "name": "go.mod",
          "size": 66,
          "time_modified": 1699944730,
          "permissions": "drwxr-xr-x"
        }
      ]
    }
  ]
}

# %%
Write the Basic Script:

Open pyls.py and write the following code to read and print the directory contents:
python

# %%
import json

# Load the JSON data
with open('structure.json') as f:
    data = json.load(f)

# Function to print the directory contents
def print_ls(contents, show_all=False):
    for item in contents:
        if not show_all and item['name'].startswith('.'):
            continue
        print(item['name'], end=' ')
    print()

# Get the top-level contents
top_level_contents = data['contents']

# Print the top-level contents
print_ls(top_level_contents)

# %%
Run the Script:

Run the script by right-clicking on pyls.py and selecting Run 'pyls'.

# %%
Step 3: Implement Command Line Arguments
Modify pyls.py to Accept Arguments:

Update pyls.py to handle command line arguments:
python

# %%
import json
import sys
import argparse

# Load the JSON data
with open('structure.json') as f:
    data = json.load(f)

# Function to print the directory contents
def print_ls(contents, show_all=False, long_format=False):
    for item in contents:
        if not show_all and item['name'].startswith('.'):
            continue
        if long_format:
            print(f"{item['permissions']} {item['size']} {item['name']}")
        else:
            print(item['name'], end=' ')
    if not long_format:
        print()

# Argument parser
parser = argparse.ArgumentParser(description='A simple implementation of ls command in Python')
parser.add_argument('-A', action='store_true', help='do not ignore entries starting with .')
parser.add_argument('-l', action='store_true', help='use a long listing format')
args = parser.parse_args()

# Get the top-level contents
top_level_contents = data['contents']

# Print the top-level contents
print_ls(top_level_contents, show_all=args.A, long_format=args.l)

# %%
Run the Script with Arguments:

Open Terminal in PyCharm and run the script with different arguments:
bash
Copy code
python pyls.py
python pyls.py -A
python pyls.py -l

# %%
Done

Subtask 1: ls (10 points)
First command to implement is ls. Name of your program should be pyls. For
the above structure, your script should parse the json file, and when run like
the following:
$ python -m pyls
Should produce the following output:
LICENSE README.md ast go.mod lexer main.go parser token

# %%
Done

Subtask 2: ls -A (2 points)
Implement the argument -A, which prints all the files and directories (including
files starting with ’.’), example:
$ python -m pyls -A
Should produce the following output:
.gitignore LICENSE README.md ast go.mod lexer main.go parser token

# %%
Partially done

Subtask 3: ls -l (10 points)
Implement the argument -l, that prints the results vertically with additional
information:
$ python -m pyls -l
-rw-r--r-- 1071 Nov 14 11:27 LICENSE
-rw-r--r-- 83 Nov 14 11:27 README.md
drwxr-xr-x 4096 Nov 14 15:58 ast
-rw-r--r-- 60 Nov 14 13:51 go.mod
drwxr-xr-x 4096 Nov 14 15:21 lexer
-rw-r--r-- 74 Nov 14 13:57 main.go
drwxr-xr-x 4096 Nov 17 12:51 parser
drwxr-xr-x 4096 Nov 14 14:57 token

Not getting expected output
output looks like

drwxr-xr-x 1071 LICENSE
drwxr-xr-x 83 README.md
-rw-r--r-- 4096 ast
drwxr-xr-x 60 go.mod
drwxr-xr-x 4096 lexer
-rw-r--r-- 74 main.go
drwxr-xr-x 4096 parser
-rw-r--r-- 4096 token

# %%
Step 4: Implement Additional Functionality
Add Reverse Order Functionality:

Update pyls.py to include the reverse order option:
python

# %%
import json
import sys
import argparse

# Load the JSON data
with open('structure.json') as f:
    data = json.load(f)

# Function to print the directory contents
def print_ls(contents, show_all=False, long_format=False, reverse=False):
    items = [item for item in contents if show_all or not item['name'].startswith('.')]
    if reverse:
        items = items[::-1]
    for item in items:
        if long_format:
            print(f"{item['permissions']} {item['size']} {item['name']}")
        else:
            print(item['name'], end=' ')
    if not long_format:
        print()

# Argument parser
parser = argparse.ArgumentParser(description='A simple implementation of ls command in Python')
parser.add_argument('-A', action='store_true', help='do not ignore entries starting with .')
parser.add_argument('-l', action='store_true', help='use a long listing format')
parser.add_argument('-r', action='store_true', help='reverse order while sorting')
args = parser.parse_args()

# Get the top-level contents
top_level_contents = data['contents']

# Print the top-level contents
print_ls(top_level_contents, show_all=args.A, long_format=args.l, reverse=args.r)

# %%
Run the Script with Reverse Order:

Open Terminal and run the script with the reverse option:
bash

# %%
python pyls.py -r
python pyls.py -A -r
python pyls.py -l -r

# %%
Step 5: Implement Sorting by Time Modified
Update pyls.py to Include Time Sorting:

Update the script to handle sorting by time modified:
python

# %%
import json
import sys
import argparse
from datetime import datetime

# Load the JSON data
with open('structure.json') as f:
    data = json.load(f)

# Function to print the directory contents
def print_ls(contents, show_all=False, long_format=False, reverse=False, sort_by_time=False):
    items = [item for item in contents if show_all or not item['name'].startswith('.')]
    if sort_by_time:
        items = sorted(items, key=lambda x: x['time_modified'], reverse=reverse)
    elif reverse:
        items = items[::-1]

    for item in items:
        if long_format:
            time_modified = datetime.fromtimestamp(item['time_modified']).strftime('%Y-%m-%d %H:%M:%S')
            print(f"{item['permissions']} {item['size']} {time_modified} {item['name']}")
        else:
            print(item['name'], end=' ')
    if not long_format:
        print()

# Argument parser
parser = argparse.ArgumentParser(description='A simple implementation of ls command in Python')
parser.add_argument('-A', action='store_true', help='do not ignore entries starting with .')
parser.add_argument('-l', action='store_true', help='use a long listing format')
parser.add_argument('-r', action='store_true', help='reverse order while sorting')
parser.add_argument('-t', action='store_true', help='sort by time modified')
args = parser.parse_args()

# Get the top-level contents
top_level_contents = data['contents']

# Print the top-level contents
print_ls(top_level_contents, show_all=args.A, long_format=args.l, reverse=args.r, sort_by_time=args.t)

# %%
Run the Script with Time Sorting:

Open Terminal and run the script with the sorting by time option:
bash

# %%
python pyls.py -t
python pyls.py -A -t
python pyls.py -l -t
python pyls.py -r -t
python pyls.py -A -r -t

# %%
output not upto the required

drwxr-xr-x 4096 2023-11-17 12:51:02 parser
-rw-r--r-- 4096 2023-11-14 15:58:59 ast
drwxr-xr-x 4096 2023-11-14 15:21:27 lexer
-rw-r--r-- 4096 2023-11-14 14:57:50 token
-rw-r--r-- 74 2023-11-14 13:57:33 main.go
drwxr-xr-x 60 2023-11-14 13:51:13 go.mod
drwxr-xr-x 1071 2023-11-14 11:27:17 LICENSE
drwxr-xr-x 83 2023-11-14 11:27:17 README.md


Then again modify the pyls.py

# %%
import json
import sys
import argparse
from datetime import datetime


def print_ls(contents, show_all=False, long_format=False, reverse=False, sort_by_time=False):
    items = [item for item in contents if show_all or not item['name'].startswith('.')]

    if sort_by_time:
        items.sort(key=lambda x: x['time_modified'], reverse=True)
    if reverse:
        items.reverse()

    for item in items:
        if long_format:
            # Convert the epoch time to the required format
            time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
            print(f"{item['permissions']} {item['size']} {time_formatted} {item['name']}")
        else:
            print(item['name'], end=' ')
    if not long_format:
        print()


def navigate_path(data, path):
    current = data
    if path in ['.', './']:
        return current['contents']
    for part in path.split('/'):
        found = False
        for item in current.get('contents', []):
            if item['name'] == part:
                if 'contents' in item:
                    current = item
                    found = True
                    break
                else:
                    return [item]
        if not found:
            print(f"error: cannot access '{path}': No such file or directory")
            sys.exit(1)
    return current['contents']


def main():
    # Load the JSON data
    with open('structure.json') as f:
        data = json.load(f)

    # Argument parser
    parser = argparse.ArgumentParser(description='A simple implementation of ls command in Python')
    parser.add_argument('-A', action='store_true', help='do not ignore entries starting with .')
    parser.add_argument('-l', action='store_true', help='use a long listing format')
    parser.add_argument('-r', action='store_true', help='reverse order while sorting')
    parser.add_argument('-t', action='store_true', help='sort by modification time, newest first')
    parser.add_argument('path', nargs='?', default='.', help='path to list (default: current directory)')
    args = parser.parse_args()

    # Navigate to the specified path
    contents = navigate_path(data, args.path)

    # Print the directory contents
    print_ls(contents, show_all=args.A, long_format=args.l, reverse=args.r, sort_by_time=args.t)


if __name__ == "__main__":
    main()

# %%
Open Terminal and run the script with the sorting by time option:
bash

python -m pyls -l -r -t

# %%
Again output not up to the required

drwxr-xr-x 83 Nov 14 11:27 README.md
drwxr-xr-x 1071 Nov 14 11:27 LICENSE
drwxr-xr-x 60 Nov 14 13:51 go.mod
-rw-r--r-- 74 Nov 14 13:57 main.go
-rw-r--r-- 4096 Nov 14 14:57 token
drwxr-xr-x 4096 Nov 14 15:21 lexer
-rw-r--r-- 4096 Nov 14 15:58 ast
drwxr-xr-x 4096 Nov 17 12:51 parser


Then again modify the pyls.py

# %%
import json
import sys
import argparse
from datetime import datetime


def print_ls(contents, show_all=False, long_format=False, reverse=False, sort_by_time=False):
    items = [item for item in contents if show_all or not item['name'].startswith('.')]

    if sort_by_time:
        items.sort(key=lambda x: x['time_modified'], reverse=True)

    if reverse and not sort_by_time:
        items.reverse()

    for item in items:
        if long_format:
            # Convert the epoch time to the required format
            time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
            file_type = 'd' if item.get('type', 'file') == 'directory' else '-'
            print(f"{file_type}{item['permissions']} {item['size']} {time_formatted} {item['name']}")
        else:
            print(item['name'], end=' ')
    if not long_format:
        print()


def navigate_path(data, path):
    current = data
    if path in ['.', './']:
        return current['contents']
    for part in path.split('/'):
        found = False
        for item in current.get('contents', []):
            if item['name'] == part:
                if 'contents' in item:
                    current = item
                    found = True
                    break
                else:
                    return [item]
        if not found:
            print(f"error: cannot access '{path}': No such file or directory")
            sys.exit(1)
    return current['contents']


def main():
    # Load the JSON data
    with open('structure.json') as f:
        data = json.load(f)

    # Argument parser
    parser = argparse.ArgumentParser(description='A simple implementation of ls command in Python')
    parser.add_argument('-A', action='store_true', help='do not ignore entries starting with .')
    parser.add_argument('-l', action='store_true', help='use a long listing format')
    parser.add_argument('-r', action='store_true', help='reverse order while sorting')
    parser.add_argument('-t', action='store_true', help='sort by modification time, newest first')
    parser.add_argument('path', nargs='?', default='.', help='path to list (default: current directory)')
    args = parser.parse_args()

    # Navigate to the specified path
    contents = navigate_path(data, args.path)

    # Print the directory contents
    print_ls(contents, show_all=args.A, long_format=args.l, reverse=args.r, sort_by_time=args.t)


if __name__ == "__main__":
    main()

# %%
Open Terminal and run the script with the sorting by time option:
bash

python -m pyls -l -r -t


Now get the expected output
-drwxr-xr-x 4096 Nov 17 12:51 parser
--rw-r--r-- 4096 Nov 14 15:58 ast
-drwxr-xr-x 4096 Nov 14 15:21 lexer
--rw-r--r-- 4096 Nov 14 14:57 token
--rw-r--r-- 74 Nov 14 13:57 main.go
-drwxr-xr-x 60 Nov 14 13:51 go.mod
-drwxr-xr-x 1071 Nov 14 11:27 LICENSE
-drwxr-xr-x 83 Nov 14 11:27 README.md

# %%
Subtask 3,4,5 done

# %%
To implement the --filter=<option> argument, we need to modify the
script to include the new argument and handle the filtering logic
based on the provided option. We will filter the output based on
whether the item is a directory or a file.

Updated pyls.py Script with --filter Option

# %%
import json
import sys
import argparse
from datetime import datetime


def print_ls(contents, show_all=False, long_format=False, reverse=False, sort_by_time=False, filter_type=None):
    items = [item for item in contents if show_all or not item['name'].startswith('.')]

    if filter_type:
        if filter_type == 'dir':
            items = [item for item in items if 'contents' in item]
        elif filter_type == 'file':
            items = [item for item in items if 'contents' not in item]
        else:
            print(f"error: '{filter_type}' is not a valid filter criteria. Available filters are 'dir' and 'file'")
            sys.exit(1)

    if sort_by_time:
        items.sort(key=lambda x: x['time_modified'], reverse=True)

    if reverse and not sort_by_time:
        items.reverse()

    for item in items:
        if long_format:
            time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
            file_type = 'd' if 'contents' in item else '-'
            print(f"{file_type}{item['permissions']} {item['size']} {time_formatted} {item['name']}")
        else:
            print(item['name'], end=' ')
    if not long_format:
        print()


def navigate_path(data, path):
    current = data
    if path in ['.', './']:
        return current['contents']
    for part in path.split('/'):
        found = False
        for item in current.get('contents', []):
            if item['name'] == part:
                if 'contents' in item:
                    current = item
                    found = True
                    break
                else:
                    return [item]
        if not found:
            print(f"error: cannot access '{path}': No such file or directory")
            sys.exit(1)
    return current['contents']


def main():
    with open('structure.json') as f:
        data = json.load(f)

    parser = argparse.ArgumentParser(description='A simple implementation of ls command in Python')
    parser.add_argument('-A', action='store_true', help='do not ignore entries starting with .')
    parser.add_argument('-l', action='store_true', help='use a long listing format')
    parser.add_argument('-r', action='store_true', help='reverse order while sorting')
    parser.add_argument('-t', action='store_true', help='sort by modification time, newest first')
    parser.add_argument('--filter', type=str, help='filter by type (file or dir)')
    parser.add_argument('path', nargs='?', default='.', help='path to list (default: current directory)')
    args = parser.parse_args()

    contents = navigate_path(data, args.path)
    print_ls(contents, show_all=args.A, long_format=args.l, reverse=args.r, sort_by_time=args.t,
             filter_type=args.filter)


if __name__ == "__main__":
    main()

# %%
Run the Script:

Run the script from the command line to see the output.

# List only directories
python -m pyls -l -r -t --filter=dir

# List only files
python -m pyls -l -r -t --filter=file

# Invalid filter option
python -m pyls -l -r -t --filter=folder

# %%
subtask 6 done

# %%
To handle paths in the JSON structure, we need to update the navigate_path
function to correctly identify and navigate directories and files based on
the provided path argument. If the path points to a file, it should print
the file itself. If it points to a directory, it should list the contents
of that directory.

the updated script that includes handling paths:

# %%
import json
import sys
import argparse
from datetime import datetime


def print_ls(contents, show_all=False, long_format=False, reverse=False, sort_by_time=False, filter_type=None):
    items = [item for item in contents if show_all or not item['name'].startswith('.')]

    if filter_type:
        if filter_type == 'dir':
            items = [item for item in items if 'contents' in item]
        elif filter_type == 'file':
            items = [item for item in items if 'contents' not in item]
        else:
            print(f"error: '{filter_type}' is not a valid filter criteria. Available filters are 'dir' and 'file'")
            sys.exit(1)

    if sort_by_time:
        items.sort(key=lambda x: x['time_modified'], reverse=True)

    if reverse and not sort_by_time:
        items.reverse()

    for item in items:
        if long_format:
            time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
            file_type = 'd' if 'contents' in item else '-'
            print(f"{file_type}{item['permissions']} {item['size']} {time_formatted} {item['name']}")
        else:
            print(item['name'], end=' ')
    if not long_format:
        print()


def navigate_path(data, path):
    if path in ['.', './']:
        return data['contents']

    parts = path.strip('/').split('/')
    current = data

    for part in parts:
        found = False
        for item in current.get('contents', []):
            if item['name'] == part:
                if 'contents' in item:
                    current = item
                else:
                    return [item]
                found = True
                break
        if not found:
            print(f"error: cannot access '{path}': No such file or directory")
            sys.exit(1)

    return current['contents']


def main():
    with open('structure.json') as f:
        data = json.load(f)

    parser = argparse.ArgumentParser(description='A simple implementation of ls command in Python')
    parser.add_argument('-A', action='store_true', help='do not ignore entries starting with .')
    parser.add_argument('-l', action='store_true', help='use a long listing format')
    parser.add_argument('-r', action='store_true', help='reverse order while sorting')
    parser.add_argument('-t', action='store_true', help='sort by modification time, newest first')
    parser.add_argument('--filter', type=str, help='filter by type (file or dir)')
    parser.add_argument('path', nargs='?', default='.', help='path to list (default: current directory)')
    args = parser.parse_args()

    contents = navigate_path(data, args.path)
    print_ls(contents, show_all=args.A, long_format=args.l, reverse=args.r, sort_by_time=args.t,
             filter_type=args.filter)


if __name__ == "__main__":
    main()

# %%
bash code

# List the contents of the 'parser' directory
python -m pyls -l parser

# List the details of the 'parser.go' file
python -m pyls -l parser/parser.go

# List the contents of the current directory
python -m pyls -l .

# %%
not getting desired output
(env) C:\Users\user\Desktop\anubhab\zuru_task\pyls_project>python -m pyls -l parser/parser.go
--rw-r--r-- 1622 Nov 17 12:05 parser.go

again modify the pyls.py

# %%
import json
import sys
import argparse
from datetime import datetime


def print_ls(contents, show_all=False, long_format=False, reverse=False, sort_by_time=False, filter_type=None):
    items = [item for item in contents if show_all or not item['name'].startswith('.')]

    if filter_type:
        if filter_type == 'dir':
            items = [item for item in items if 'contents' in item]
        elif filter_type == 'file':
            items = [item for item in items if 'contents' not in item]
        else:
            print(f"error: '{filter_type}' is not a valid filter criteria. Available filters are 'dir' and 'file'")
            sys.exit(1)

    if sort_by_time:
        items.sort(key=lambda x: x['time_modified'], reverse=True)

    if reverse and not sort_by_time:
        items.reverse()

    for item in items:
        if long_format:
            time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
            file_type = 'd' if 'contents' in item else '-'
            print(f"{file_type}{item['permissions']} {item['size']} {time_formatted} {item['name']}")
        else:
            print(item['name'], end=' ')
    if not long_format:
        print()


def navigate_path(data, path):
    if path in ['.', './']:
        return data['contents']

    parts = path.strip('/').split('/')
    current = data

    for part in parts:
        found = False
        for item in current.get('contents', []):
            if item['name'] == part:
                if 'contents' in item:
                    current = item
                else:
                    return [item]
                found = True
                break
        if not found:
            print(f"error: cannot access '{path}': No such file or directory")
            sys.exit(1)

    return current['contents']


def main():
    with open('structure.json') as f:
        data = json.load(f)

    parser = argparse.ArgumentParser(description='A simple implementation of ls command in Python')
    parser.add_argument('-A', action='store_true', help='do not ignore entries starting with .')
    parser.add_argument('-l', action='store_true', help='use a long listing format')
    parser.add_argument('-r', action='store_true', help='reverse order while sorting')
    parser.add_argument('-t', action='store_true', help='sort by modification time, newest first')
    parser.add_argument('--filter', type=str, help='filter by type (file or dir)')
    parser.add_argument('path', nargs='?', default='.', help='path to list (default: current directory)')
    args = parser.parse_args()

    contents = navigate_path(data, args.path)

    if len(contents) == 1 and 'contents' not in contents[0]:
        # Path is a file
        item = contents[0]
        if args.l:
            time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
            file_type = '-' if 'contents' not in item else 'd'
            print(f"{file_type}{item['permissions']} {item['size']} {time_formatted} ./{args.path}")
        else:
            print(args.path)
    else:
        # Path is a directory
        print_ls(contents, show_all=args.A, long_format=args.l, reverse=args.r, sort_by_time=args.t,
                 filter_type=args.filter)


if __name__ == "__main__":
    main()

# %%
not getting desired output

(env) C:\Users\user\Desktop\anubhab\zuru_task\pyls_project>python pyls non_existent_path
C:\Users\user\AppData\Local\Programs\Python\Python312\python.exe: can't open file 'C:\\Users\\user\\Desktop\\anubhab\\zuru_task\\pyls_project\\pyls': [Errno 2] No such file or directory

# %%
It appears that the pyls module is not being recognized when you use python -m pyls directly. Let's ensure that we set up the script correctly so that it can be run as a module. To achieve this, we need to create a package structure.

Here's how to adjust the setup:

Directory Structure:
Ensure that your directory structure looks like this:



pyls_project/
├── pyls/
│   ├── __init__.py
│   └── pyls.py
└── structure.json

Contents of __init__.py:
Leave this file empty or with a comment:

# This file is required to make this directory a package.
Contents of pyls.py:
Move the entire contents of your current pyls.py into the pyls directory.

Updated pyls.py Script

# %%
import json
import sys
import argparse
from datetime import datetime

def print_ls(contents, show_all=False, long_format=False, reverse=False, sort_by_time=False, filter_type=None):
    items = [item for item in contents if show_all or not item['name'].startswith('.')]

    if filter_type:
        if filter_type == 'dir':
            items = [item for item in items if 'contents' in item]
        elif filter_type == 'file':
            items = [item for item in items if 'contents' not in item]
        else:
            print(f"error: '{filter_type}' is not a valid filter criteria. Available filters are 'dir' and 'file'")
            sys.exit(1)

    if sort_by_time:
        items.sort(key=lambda x: x['time_modified'], reverse=True)

    if reverse and not sort_by_time:
        items.reverse()

    for item in items:
        if long_format:
            time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
            file_type = 'd' if 'contents' in item else '-'
            print(f"{file_type}{item['permissions']} {item['size']} {time_formatted} {item['name']}")
        else:
            print(item['name'], end=' ')
    if not long_format:
        print()

def navigate_path(data, path):
    if path in ['.', './']:
        return data['contents']

    parts = path.strip('/').split('/')
    current = data

    for part in parts:
        found = False
        for item in current.get('contents', []):
            if item['name'] == part:
                if 'contents' in item:
                    current = item
                else:
                    return [item]
                found = True
                break
        if not found:
            print(f"error: cannot access '{path}': No such file or directory")
            sys.exit(1)

    return current['contents']

def main():
    with open('structure.json') as f:
        data = json.load(f)

    parser = argparse.ArgumentParser(description='A simple implementation of ls command in Python')
    parser.add_argument('-A', action='store_true', help='do not ignore entries starting with .')
    parser.add_argument('-l', action='store_true', help='use a long listing format')
    parser.add_argument('-r', action='store_true', help='reverse order while sorting')
    parser.add_argument('-t', action='store_true', help='sort by modification time, newest first')
    parser.add_argument('--filter', type=str, help='filter by type (file or dir)')
    parser.add_argument('path', nargs='?', default='.', help='path to list (default: current directory)')
    args = parser.parse_args()

    try:
        contents = navigate_path(data, args.path)

        if len(contents) == 1 and 'contents' not in contents[0]:
            # Path is a file
            item = contents[0]
            if args.l:
                time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
                file_type = '-' if 'contents' not in item else 'd'
                print(f"{file_type}{item['permissions']} {item['size']} {time_formatted} ./{args.path}")
            else:
                print(args.path)
        else:
            # Path is a directory
            print_ls(contents, show_all=args.A, long_format=args.l, reverse=args.r, sort_by_time=args.t, filter_type=args.filter)
    except KeyError:
        print(f"error: cannot access '{args.path}': No such file or directory")
        sys.exit(1)

if __name__ == "__main__":
    main()

# %%
Test the script with various commands to ensure it handles paths, files, and directories correctly. Make sure to run the commands from the pyls_project directory:

bash

# List the contents of the 'parser' directory
python -m pyls.pyls -l parser

# List the details of the 'parser.go' file
python -m pyls.pyls -l parser/parser.go

# List the contents of the current directory
python -m pyls.pyls -l .

# Test a non-existent path
python -m pyls.pyls non_existent_path

# %%
subtask 7 done

# %%
To add human-readable file sizes to your pyls implementation,need to modify the print_ls function to convert
file sizes into a more readable format (e.g., KB, MB, GB). Here’s how we can update our script to handle the -h option:

Updated pyls.py Script
Add a helper function to convert bytes into a human-readable format and integrate it into the print_ls function.

# %%
import json
import sys
import argparse
from datetime import datetime

def human_readable_size(size):
    """Convert bytes to a human-readable format."""
    for unit in ['B', 'K', 'M', 'G', 'T']:
        if size < 1024:
            return f"{size:.1f}{unit}"
        size /= 1024
    return f"{size:.1f}P"

def print_ls(contents, show_all=False, long_format=False, reverse=False, sort_by_time=False, filter_type=None, human_readable=False):
    items = [item for item in contents if show_all or not item['name'].startswith('.')]

    if filter_type:
        if filter_type == 'dir':
            items = [item for item in items if 'contents' in item]
        elif filter_type == 'file':
            items = [item for item in items if 'contents' not in item]
        else:
            print(f"error: '{filter_type}' is not a valid filter criteria. Available filters are 'dir' and 'file'")
            sys.exit(1)

    if sort_by_time:
        items.sort(key=lambda x: x['time_modified'], reverse=True)

    if reverse and not sort_by_time:
        items.reverse()

    for item in items:
        if long_format:
            time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
            file_type = 'd' if 'contents' in item else '-'
            size = human_readable_size(item['size']) if human_readable else item['size']
            print(f"{file_type}{item['permissions']} {size} {time_formatted} {item['name']}")
        else:
            print(item['name'], end=' ')
    if not long_format:
        print()

def navigate_path(data, path):
    if path in ['.', './']:
        return data['contents']

    parts = path.strip('/').split('/')
    current = data

    for part in parts:
        found = False
        for item in current.get('contents', []):
            if item['name'] == part:
                if 'contents' in item:
                    current = item
                else:
                    return [item]
                found = True
                break
        if not found:
            print(f"error: cannot access '{path}': No such file or directory")
            sys.exit(1)

    return current['contents']

def main():
    with open('structure.json') as f:
        data = json.load(f)

    parser = argparse.ArgumentParser(description='A simple implementation of ls command in Python')
    parser.add_argument('-A', action='store_true', help='do not ignore entries starting with .')
    parser.add_argument('-l', action='store_true', help='use a long listing format')
    parser.add_argument('-r', action='store_true', help='reverse order while sorting')
    parser.add_argument('-t', action='store_true', help='sort by modification time, newest first')
    parser.add_argument('-h', action='store_true', help='human-readable sizes')
    parser.add_argument('--filter', type=str, help='filter by type (file or dir)')
    parser.add_argument('path', nargs='?', default='.', help='path to list (default: current directory)')
    args = parser.parse_args()

    try:
        contents = navigate_path(data, args.path)

        if len(contents) == 1 and 'contents' not in contents[0]:
            # Path is a file
            item = contents[0]
            if args.l:
                size = human_readable_size(item['size']) if args.h else item['size']
                time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
                file_type = '-' if 'contents' not in item else 'd'
                print(f"{file_type}{item['permissions']} {size} {time_formatted} ./{args.path}")
            else:
                print(args.path)
        else:
            # Path is a directory
            print_ls(contents, show_all=args.A, long_format=args.l, reverse=args.r, sort_by_time=args.t, filter_type=args.filter, human_readable=args.h)
    except KeyError:
        print(f"error: cannot access '{args.path}': No such file or directory")
        sys.exit(1)

if __name__ == "__main__":
    main()

# %%
Human Readable Size Conversion:

Added human_readable_size function to convert bytes into a human-readable format with units (B, K, M, G, T).
Handling -h Option:

Added -h argument to the argument parser.
Integrated human-readable size formatting in print_ls and in the file path handling section.

# %%
Testing
Make sure to test with various options to confirm that the sizes are displayed in a human-readable format:

bash

# Test human-readable sizes
python -m pyls.pyls -l -h
python -m pyls.pyls -l -h parser
python -m pyls.pyls -l parser

# %%
getting error
argparse.ArgumentError: argument -h: conflicting option string: -h


The error you’re encountering indicates that there's a conflict with the -h argument, which is reserved by argparse for displaying help messages. To avoid this conflict, you should use a different flag for the human-readable sizes option.

Here’s how you can modify the pyls.py script:

Change the -h Option to Another Flag:
Use a different flag, such as -H, for the human-readable sizes option. This will avoid the conflict with the default -h help flag.
Updated pyls.py
Replace your existing pyls.py with this version:

# %%
import argparse
import json
import os
import sys
from datetime import datetime


def human_readable_size(size):
    """Convert bytes to a human-readable format."""
    if size < 1024:
        return f"{size}B"
    size /= 1024
    if size < 1024:
        return f"{size:.1f}K"
    size /= 1024
    if size < 1024:
        return f"{size:.1f}M"
    size /= 1024
    return f"{size:.1f}G"


def print_ls(contents, show_all=False, long_format=False, reverse=False, sort_by_time=False, filter_type=None,
             human_readable=False):
    """Prints the directory listing in a format similar to the `ls` command."""
    # Filter items based on the filter_type
    items = [item for item in contents if show_all or not item['name'].startswith('.')]

    if filter_type:
        if filter_type == 'dir':
            items = [item for item in items if 'contents' in item]
        elif filter_type == 'file':
            items = [item for item in items if 'contents' not in item]
        else:
            print(f"error: '{filter_type}' is not a valid filter criteria. Available filters are 'dir' and 'file'")
            sys.exit(1)

    if sort_by_time:
        items.sort(key=lambda x: x['time_modified'], reverse=True)

    if reverse and not sort_by_time:
        items.reverse()

    for item in items:
        if long_format:
            time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
            file_type = 'd' if 'contents' in item else '-'
            size = human_readable_size(item['size']) if human_readable else item['size']
            permissions = item['permissions']
            print(f"{file_type}{permissions} {size:>6} {time_formatted} {item['name']}")
        else:
            print(item['name'], end=' ')
    if not long_format:
        print()


def navigate_path(data, path):
    """Navigate through the JSON structure to find the path."""
    path_parts = path.strip('./').split('/')
    current = data['contents'] if 'contents' in data else data

    if not path_parts[0]:  # Current directory
        return current

    for part in path_parts:
        found = False
        for item in current:
            if isinstance(item, dict) and item.get('name') == part:
                if 'contents' in item:
                    current = item['contents']
                    found = True
                else:
                    return [item]
                break
        if not found:
            raise KeyError("No such file or directory")

    return current


def main():
    with open('structure.json') as f:
        data = json.load(f)

    parser = argparse.ArgumentParser(description='A simple implementation of ls command in Python')
    parser.add_argument('-A', action='store_true', help='do not ignore entries starting with .')
    parser.add_argument('-l', action='store_true', help='use a long listing format')
    parser.add_argument('-r', action='store_true', help='reverse order while sorting')
    parser.add_argument('-t', action='store_true', help='sort by modification time, newest first')
    parser.add_argument('-H', action='store_true', help='human-readable sizes')
    parser.add_argument('--filter', type=str, help='filter by type (file or dir)')
    parser.add_argument('path', nargs='?', default='.', help='path to list (default: current directory)')
    args = parser.parse_args()

    try:
        contents = navigate_path(data, args.path)

        if len(contents) == 1 and 'contents' not in contents[0]:
            # Path is a file
            item = contents[0]
            if args.l:
                size = human_readable_size(item['size']) if args.H else item['size']
                time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
                file_type = '-' if 'contents' not in item else 'd'
                print(f"{file_type}{item['permissions']} {size:>6} {time_formatted} {args.path}")
            else:
                print(args.path)
        else:
            # Path is a directory
            print_ls(contents, show_all=args.A, long_format=args.l, reverse=args.r, sort_by_time=args.t,
                     filter_type=args.filter, human_readable=args.H)
    except KeyError:
        print(f"error: cannot access '{args.path}': No such file or directory")
        sys.exit(1)


if __name__ == "__main__":
    main()

# %%
Testing
Make sure to test with various options to confirm that the sizes are displayed in a human-readable format:

bash

python -m pyls.pyls -l parser -H

# %%
Question 8 done

# %%
To implement the --help option for your script, you need to make sure that
the argparse.ArgumentParser is correctly configured to provide a helpful
message when the --help flag is used. This is already partially implemented
in the script, but we can enhance it to ensure it meets all the requirements
for a detailed help message.

updated pyls.py

# %%
import argparse
import json
import os
import sys
from datetime import datetime

def human_readable_size(size):
    """Convert bytes to a human-readable format."""
    if size < 1024:
        return f"{size}B"
    size /= 1024
    if size < 1024:
        return f"{size:.1f}K"
    size /= 1024
    if size < 1024:
        return f"{size:.1f}M"
    size /= 1024
    return f"{size:.1f}G"

def print_ls(contents, show_all=False, long_format=False, reverse=False, sort_by_time=False, filter_type=None, human_readable=False):
    """Prints the directory listing in a format similar to the `ls` command."""
    # Filter items based on the filter_type
    items = [item for item in contents if show_all or not item['name'].startswith('.')]

    if filter_type:
        if filter_type == 'dir':
            items = [item for item in items if 'contents' in item]
        elif filter_type == 'file':
            items = [item for item in items if 'contents' not in item]
        else:
            print(f"error: '{filter_type}' is not a valid filter criteria. Available filters are 'dir' and 'file'")
            sys.exit(1)

    if sort_by_time:
        items.sort(key=lambda x: x['time_modified'], reverse=True)

    if reverse and not sort_by_time:
        items.reverse()

    for item in items:
        if long_format:
            time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
            file_type = 'd' if 'contents' in item else '-'
            size = human_readable_size(item['size']) if human_readable else item['size']
            permissions = item['permissions']
            print(f"{file_type}{permissions} {size:>6} {time_formatted} {item['name']}")
        else:
            print(item['name'], end=' ')
    if not long_format:
        print()

def navigate_path(data, path):
    """Navigate through the JSON structure to find the path."""
    path_parts = path.strip('./').split('/')
    current = data['contents'] if 'contents' in data else data

    if not path_parts[0]:  # Current directory
        return current

    for part in path_parts:
        found = False
        for item in current:
            if isinstance(item, dict) and item.get('name') == part:
                if 'contents' in item:
                    current = item['contents']
                    found = True
                else:
                    return [item]
                break
        if not found:
            raise KeyError("No such file or directory")

    return current

def main():
    with open('structure.json') as f:
        data = json.load(f)

    parser = argparse.ArgumentParser(
        description='A simple implementation of ls command in Python',
        usage='python -m pyls.pyls [options] [path]',
        formatter_class=argparse.RawTextHelpFormatter
    )
    parser.add_argument('-A', action='store_true', help='do not ignore entries starting with .')
    parser.add_argument('-l', action='store_true', help='use a long listing format')
    parser.add_argument('-r', action='store_true', help='reverse order while sorting')
    parser.add_argument('-t', action='store_true', help='sort by modification time, newest first')
    parser.add_argument('-H', action='store_true', help='human-readable sizes')
    parser.add_argument('--filter', type=str, choices=['file', 'dir'], help='filter by type (file or dir)')
    parser.add_argument('path', nargs='?', default='.', help='path to list (default: current directory)')
    args = parser.parse_args()

    try:
        contents = navigate_path(data, args.path)

        if len(contents) == 1 and 'contents' not in contents[0]:
            # Path is a file
            item = contents[0]
            if args.l:
                size = human_readable_size(item['size']) if args.H else item['size']
                time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
                file_type = '-' if 'contents' not in item else 'd'
                print(f"{file_type}{item['permissions']} {size:>6} {time_formatted} {args.path}")
            else:
                print(args.path)
        else:
            # Path is a directory
            print_ls(contents, show_all=args.A, long_format=args.l, reverse=args.r, sort_by_time=args.t, filter_type=args.filter, human_readable=args.H)
    except KeyError:
        print(f"error: cannot access '{args.path}': No such file or directory")
        sys.exit(1)

if __name__ == "__main__":
    main()

# %%
Test the code in bash

python -m pyls.pyls --help

# %%
Question 9 done

# %%
To include a pyproject.toml file and configure it so that installing the project using pip adds a pyls system command, follow these steps:

1. Project Structure
Ensure your project structure looks like this:

markdown
Copy code
pyls_project/
├── pyls/
│   ├── __init__.py
│   └── pyls.py
├── structure.json
├── pyproject.toml
└── README.md

# %%
2. pyproject.toml File
Create a pyproject.toml file with the following content:

# %%
[build-system]
requires = ["setuptools", "wheel"]
build-backend = "setuptools.build_meta"

[project]
name = "pyls"
version = "0.1.0"
description = "A simple implementation of the ls command in Python"
readme = "README.md"
license = { file = "LICENSE" }
authors = [
    { name = "Your Name", email = "your.email@example.com" }
]
dependencies = []

[project.scripts]
pyls = "pyls.pyls:main"

# %%
5. pyls.py File
Ensure your pyls.py file contains the correct code. Here is a simplified version:

# %%
import argparse
import json
import os
import sys
from datetime import datetime

def human_readable_size(size):
    """Convert bytes to a human-readable format."""
    if size < 1024:
        return f"{size}B"
    size /= 1024
    if size < 1024:
        return f"{size:.1f}K"
    size /= 1024
    if size < 1024:
        return f"{size:.1f}M"
    size /= 1024
    return f"{size:.1f}G"

def print_ls(contents, show_all=False, long_format=False, reverse=False, sort_by_time=False, filter_type=None, human_readable=False):
    """Prints the directory listing in a format similar to the `ls` command."""
    items = [item for item in contents if show_all or not item['name'].startswith('.')]
    if filter_type:
        if filter_type == 'dir':
            items = [item for item in items if 'contents' in item]
        elif filter_type == 'file':
            items = [item for item in items if 'contents' not in item]
        else:
            print(f"error: '{filter_type}' is not a valid filter criteria. Available filters are 'dir' and 'file'")
            sys.exit(1)
    if sort_by_time:
        items.sort(key=lambda x: x['time_modified'], reverse=True)
    if reverse and not sort_by_time:
        items.reverse()
    for item in items:
        if long_format:
            time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
            file_type = 'd' if 'contents' in item else '-'
            size = human_readable_size(item['size']) if human_readable else item['size']
            permissions = item['permissions']
            print(f"{file_type}{permissions} {size:>6} {time_formatted} {item['name']}")
        else:
            print(item['name'], end=' ')
    if not long_format:
        print()

def navigate_path(data, path):
    """Navigate through the JSON structure to find the path."""
    path_parts = path.strip('./').split('/')
    current = data['contents'] if 'contents' in data else data
    if not path_parts[0]:  # Current directory
        return current
    for part in path_parts:
        found = False
        for item in current:
            if isinstance(item, dict) and item.get('name') == part:
                if 'contents' in item:
                    current = item['contents']
                    found = True
                else:
                    return [item]
                break
        if not found:
            raise KeyError("No such file or directory")
    return current

def main():
    with open('structure.json') as f:
        data = json.load(f)
    parser = argparse.ArgumentParser(
        description='A simple implementation of ls command in Python',
        usage='python -m pyls.pyls [options] [path]',
        formatter_class=argparse.RawTextHelpFormatter
    )
    parser.add_argument('-A', action='store_true', help='do not ignore entries starting with .')
    parser.add_argument('-l', action='store_true', help='use a long listing format')
    parser.add_argument('-r', action='store_true', help='reverse order while sorting')
    parser.add_argument('-t', action='store_true', help='sort by modification time, newest first')
    parser.add_argument('-H', action='store_true', help='human-readable sizes')
    parser.add_argument('--filter', type=str, choices=['file', 'dir'], help='filter by type (file or dir)')
    parser.add_argument('path', nargs='?', default='.', help='path to list (default: current directory)')
    args = parser.parse_args()
    try:
        contents = navigate_path(data, args.path)
        if len(contents) == 1 and 'contents' not in contents[0]:
            # Path is a file
            item = contents[0]
            if args.l:
                size = human_readable_size(item['size']) if args.H else item['size']
                time_formatted = datetime.fromtimestamp(item['time_modified']).strftime('%b %d %H:%M')
                file_type = '-' if 'contents' not in item else 'd'
                print(f"{file_type}{item['permissions']} {size:>6} {time_formatted} {args.path}")
            else:
                print(args.path)
        else:
            # Path is a directory
            print_ls(contents, show_all=args.A, long_format=args.l, reverse=args.r, sort_by_time=args.t, filter_type=args.filter, human_readable=args.H)
    except KeyError:
        print(f"error: cannot access '{args.path}': No such file or directory")
        sys.exit(1)

if __name__ == "__main__":
    main()

# %%
6. Installing the Package
Navigate to your project directory:

bash

cd path/to/your/pyls_project

Install the package using pip:

bash

pip install .

7. Running the pyls Command
After installation, you should be able to run the pyls command directly from the terminal:

bash

pyls

# %%
Bonus Question done
